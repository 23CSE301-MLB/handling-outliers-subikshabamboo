# %%
import pandas as pd
df=pd.read_csv('credit_scoring_eng.csv')
df
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 0             1   -8437.673028         42       masters degree             0
# 1             1   -4024.803754         36  secondary education             1
# 2             0   -5623.422610         33  Secondary Education             1
# 3             3   -4124.747207         32  secondary education             1
# 4             0  340266.072047         53  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 21520         1   -4529.316663         43  secondary education             1
# 21521         0  343937.404131         67  secondary education             1
# 21522         1   -2113.346888         38  secondary education             1
# 21523         3   -3112.481705         38  secondary education             1
# 21524         2   -1984.507589         40  secondary education             1
#
# ...

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt  total_income
# count      21525.000000  21525.000000  1.935100e+04
# mean           0.972544      0.080883  1.674223e+05
# std            1.420324      0.272661  1.029716e+05
# min            0.000000      0.000000  2.066726e+04
# 25%            0.000000      0.000000  1.030532e+05
# 50%            0.000000      0.000000  1.450179e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (21525, 12)

# %%
df.groupby(df['children']).mean(numeric_only=True)
# Out:
#           days_employed  dob_years  education_id  family_status_id      debt  \
# children
# -1         55013.536077  42.574468      0.829787          0.957447  0.021277
#  0         88782.178434  46.261432      0.831225          1.120927  0.075129
#  1         19020.664653  38.366127      0.786841          0.806144  0.092154
#  2          1274.234500  35.770316      0.788808          0.451095  0.094404
#  3          5075.166414  36.287879      0.824242          0.403030  0.081818
#  4          9631.442976  36.048780      0.780488          0.512195  0.097561
#  5         -1432.348601  38.777778      1.222222          0.222222  0.000000
#  20        35779.535997  41.815789      0.842105          0.815789  0.105263
#
#            total_income
# children
# -1        153863.178346
#  0        165140.030422
#  1        171228.087764
#  2        171852.236814
#  3        183266.400040
#  4        170561.435135
#  5        170430.295564
#  20       168720.526180

# %%
df.sort_values('dob_years',ascending=False)
# Out:
#        children  days_employed  dob_years            education  education_id  \
# 8880          0   -1678.969771         75  secondary education             1
# 2557          0  372861.103965         74  secondary education             1
# 3460          0  344623.836105         74  secondary education             1
# 19642         0  380150.387046         74  secondary education             1
# 11532         0   -6682.867814         74  secondary education             1
# ...         ...            ...        ...                  ...           ...
# 15295         0   -1245.658244          0  secondary education             1
# 8574          0            NaN          0  secondary education             1
# 10384         1   -1605.506161          0       masters degree             0
# 13187         0    -334.837285          0  SECONDARY EDUCATION             1
# 8061          0  366457.872613          0       masters degree             0
#
# ...

# %%
df.iloc[50:60]
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 50         0  353731.432338         63  secondary education             1
# 51         1   -6953.631655         50       masters degree             0
# 52         1   -3554.671526         28  secondary education             1
# 53         0   -4219.883386         61  SECONDARY EDUCATION             1
# 54         0   -3480.072793         27       masters degree             0
# 55         0            NaN         54  secondary education             1
# 56         0  370145.087237         64  secondary education             1
# 57         0   -2424.809749         44  secondary education             1
# 58         0    -335.318630         36       masters degree             0
# 59         0   -4341.786775         53  secondary education             1
#
#         family_status  family_status_id gender income_type  debt  \
# 50            married                 0      F     retiree     0
# ...

# %%
df.loc[50:60]
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 50         0  353731.432338         63  secondary education             1
# 51         1   -6953.631655         50       masters degree             0
# 52         1   -3554.671526         28  secondary education             1
# 53         0   -4219.883386         61  SECONDARY EDUCATION             1
# 54         0   -3480.072793         27       masters degree             0
# 55         0            NaN         54  secondary education             1
# 56         0  370145.087237         64  secondary education             1
# 57         0   -2424.809749         44  secondary education             1
# 58         0    -335.318630         36       masters degree             0
# 59         0   -4341.786775         53  secondary education             1
# 60         1   -2534.462390         48  secondary education             1
#
#         family_status  family_status_id gender income_type  debt  \
# ...

# %%
pd.crosstab(df['children'],df['family_status'])
# Out:
# family_status  civil partnership  divorced  married  unmarried  \
# children
# -1                             5         4       29          5
#  0                          2752       784     7500       2265
#  1                           998       312     2982        449
#  2                           344        81     1535         75
#  3                            56        11      249          8
#  4                             8         1       29          2
#  5                             2         0        7          0
#  20                           12         2       49          9
#
# family_status  widow / widower
# children
# -1                           4
#  0                         848
#  1                          77
#  2                          20
#  3                           6
#  4                           1
#  5                           0
#  20                          4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='total_income',data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='debt',data=df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(x='days_employed',data=df)
plt.show()

# %%
import numpy as np
from scipy import stats
z_scores= np.abs(stats.zscore(df['total_income']))
outliers_z= df[z_scores> 3]
print(outliers_z.shape)
# Out:
# (0, 12)

# %%
import numpy as np
from scipy import stats
z_scores= np.abs(stats.zscore(df['debt']))
outliers_z= df[z_scores> 3]
print(outliers_z.shape)
# Out:
# (1741, 12)

# %%
import numpy as np
from scipy import stats
z_scores= np.abs(stats.zscore(df['days_employed']))
outliers_z= df[z_scores> 3]
print(outliers_z.shape)
# Out:
# (0, 12)

# %%
Q1 = df['total_income'].quantile(0.25)
Q3 = df['total_income'].quantile(0.75)
IQR = Q3 -Q1
lower_bound= Q1 -1.5 * IQR
upper_bound= Q3 + 1.5 * IQR
outliers_iqr= df[(df['total_income'] < lower_bound) | 
(df['total_income'] > upper_bound)]
print(outliers_iqr.shape)
# Out:
# (818, 12)

# %%
Q1 = df['debt'].quantile(0.25)
Q3 = df['debt'].quantile(0.75)
IQR = Q3 -Q1
lower_bound= Q1 -1.5 * IQR
upper_bound= Q3 + 1.5 * IQR
outliers_iqr= df[(df['debt'] < lower_bound) | 
(df['debt'] > upper_bound)]
print(outliers_iqr.shape)
# Out:
# (1741, 12)

# %%
Q1=df['days_employed'].quantile(0.25)
Q3=df['days_employed'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q1+1.5*IQR
outliers_iqr=df[(df['days_employed']<lower_bound)| (df['days_employed']>upper_bound)]
print(outliers_iqr.shape)
# Out:
# (4467, 12)

# %%
df_capped= df.copy()
df_capped['total_income'] = np.where(df_capped['total_income'] > upper_bound, upper_bound,
np.where(df_capped['total_income'] < lower_bound, 
lower_bound, df_capped['total_income']))

# %%
df_capped= df.copy()
df_capped['debt'] = np.where(df_capped['debt'] > upper_bound, upper_bound,
np.where(df_capped['debt'] < lower_bound, 
lower_bound, df_capped['debt']))

# %%
df_capped= df.copy()
df_capped['days_employed'] = np.where(df_capped['days_employed'] > upper_bound, upper_bound,
np.where(df_capped['days_employed'] < lower_bound, 
lower_bound, df_capped['days_employed']))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['study'] = le.fit_transform(df['education'])

# %%
df['study']
# Out:
# 0        12
# 1        14
# 2         9
# 3        14
# 4        14
#          ..
# 21520    14
# 21521    14
# 21522    14
# 21523    14
# 21524    14
# Name: study, Length: 21525, dtype: int64

# %%
#after removing outliers
sns.barplot(x='total_income',data=df_capped)
plt.show()

# %%
#after removing outliers
sns.barplot(x='debt',data=df_capped)
plt.show()

# %%
#after removing outliers
sns.barplot(x='days_employed',data=df_capped)
plt.show()
